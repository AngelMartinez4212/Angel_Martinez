# %%
#a.Extraer la información del archivo
import pandas as pd
vaccinations = pd.read_csv("/content/drive/MyDrive/Diplomado Data Scientist/Pandas/country_vaccinations.csv")
vaccinations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  object
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
# ...

# %%
#b.Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurandote que las columnas con fechas sean del tipo datetime64.
vaccinations = pd.read_csv("/content/drive/MyDrive/Diplomado Data Scientist/Pandas/country_vaccinations.csv")
vaccinations["date"] = pd.to_datetime(vaccinations["date"])
vaccinations.head(5)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
#c.Determinar la cantidad de vacunas aplicadas de cada compañía (en base a como lo reporta cada país en la columna vaccines)
vaccinations[["vaccines","country"]].groupby("vaccines").count()
# Out:
#                                                     country
# vaccines
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pf...      390
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/Bio...      381
# Abdala, Sinopharm/Beijing, Sinovac, Soberana02,...      402
# Abdala, Soberana Plus, Soberana02                       320
# COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/Ast...      415
# ...                                                     ...
# Pfizer/BioNTech, Sinovac, Turkovac                      441
# Pfizer/BioNTech, Sputnik V                              387
# QazVac, Sinopharm/Beijing, Sputnik V                    423
# Sinopharm/Beijing                                       809
# Sinopharm/Beijing, Sputnik V                            815
#
# [84 rows x 1 columns]

# %%
#d.Obtener la cantidad de vacunas aplicadas en todo el mundo
vaccinations["total_vaccinations"].sum()
# Out:
# 2002854013761.0

# %%
#e.Calcular el promedio de vacunas aplicadas por país
vaccinations[["country","total_vaccinations"]].groupby("country").mean()
# Out:
#                    total_vaccinations
# country
# Afghanistan              2.566118e+06
# Albania                  1.191695e+06
# Algeria                  9.956086e+06
# Andorra                  5.827721e+04
# Angola                   6.074066e+06
# ...                               ...
# Wales                    4.132861e+06
# Wallis and Futuna        9.142925e+03
# Yemen                    4.794049e+05
# Zambia                   1.048484e+06
# Zimbabwe                 4.181618e+06
#
# [223 rows x 1 columns]

# %%
#f.Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo
vaccinations[vaccinations["date"]== "2021-01-29"]["total_vaccinations"].sum()
# Out:
# 82952931.0

# %%
#g.Crear un dataframe nuevo denoninado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw
conDiferencias = vaccinations
conDiferencias["diferencias"] = conDiferencias["daily_vaccinations"] - conDiferencias["daily_vaccinations_raw"]
conDiferencias.tail(5)
# Out:
#         country iso_code       date  total_vaccinations  people_vaccinated  \
# 86507  Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508  Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509  Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510  Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511  Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 86507                3473523.0                139213.0             69579.0
# 86508                3487962.0                100086.0             83429.0
# 86509                3493763.0                 53311.0             90629.0
# 86510                3501493.0                 89321.0            100614.0
# 86511                3510256.0                105369.0            103751.0
#
# ...

# %%
#h.Obtener el período de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua
vaccinations["date"].max() - vaccinations["date"].min()
# Out:
# Timedelta('482 days 00:00:00')

# %%
#i.Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter / )
conCantidad = vaccinations
conCantidad["canVac"] = conCantidad["vaccines"].str.split("/").str.len()
conCantidad.head(5)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
#j.Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020
antes20 = vaccinations.query('date<"2020-12-20"')
antes20.head(5)
# Out:
#       country iso_code       date  total_vaccinations  people_vaccinated  \
# 13403  Canada      CAN 2020-12-14                 5.0                5.0
# 13404  Canada      CAN 2020-12-15               727.0              727.0
# 13405  Canada      CAN 2020-12-16              3025.0             3025.0
# 13406  Canada      CAN 2020-12-17              7279.0             7279.0
# 13407  Canada      CAN 2020-12-18             11296.0            11296.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 13403                      NaN                     NaN                 NaN
# 13404                      NaN                   722.0               722.0
# 13405                      NaN                  2298.0              1510.0
# 13406                      NaN                  4254.0              2425.0
# 13407                      NaN                  4017.0              2823.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
#k.Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer.
pfizer = vaccinations[vaccinations["vaccines"].str.contains("Pfizer")]
pfizer.head(5)
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
#l. Almacenar los dataframes generados (conDiferencias,conCantidad,antes20 y pfizer) en un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter
import pandas as pd
writter = pd.ExcelWriter("/content/drive/MyDrive/Diplomado Data Scientist/Pandas/resultadosReto.xlsx")
vaccinations.to_excel(writter, sheet_name="country_vaccinations", index=False)
conDiferencias.to_excel(writter, sheet_name="conDiferencias", index=False)
conCantidad.to_excel(writter, sheet_name="conCantidad", index=False)
antes20.to_excel(writter, sheet_name="antes20", index=False)
pfizer.to_excel(writter, sheet_name="Pfizer", index=False)
writter.close()
